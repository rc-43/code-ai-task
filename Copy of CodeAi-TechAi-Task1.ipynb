# %% [markdown]
# # ***FOR DOING THE TASK MAKE THE COPY OF THIS COLLAB FILE IN YOUR DRIVE***

# %% [markdown]
# ### 1. Python Basics & Control Structures
#
# *Task*:
#
# * Write a Python program that:
#
#   * Takes a list of strings (e.g., ["apple", "banana", "grape", "kiwi", "orange"]).
#   * Filters out fruits with more than 5 characters using a for loop and if statement.
#   * For each fruit, print its length.
#
# *Example Input*:
#
# python
# fruits = ["apple", "banana", "grape", "kiwi", "orange"]

# %%
fruits=[]
while(True):
  n=input("enter the fruits u want or enter stop if finished: ")
  if(n=="stop"):
      break
  fruits.append(n)
for x in fruits:
  if(len(x)<=5):
      print("the fruit {} has {} characters".format(x,len(x)))
# Out:
# enter the fruits u want or enter stop if finished: banana
# enter the fruits u want or enter stop if finished: orange
# enter the fruits u want or enter stop if finished: apple
# enter the fruits u want or enter stop if finished: kiwi
# enter the fruits u want or enter stop if finished: stop
# the fruit apple has 5 characters
# the fruit kiwi has 4 characters

# %% [markdown]
# *Expected Output*:
#
#
# The fruit apple has 5 characters.
#
# The fruit banana has 6 characters.
#
# The fruit orange has 6 characters.

# %% [markdown]
# ### 2. Functions & Lambda
#
# *Task*:
#
# * Write a function that takes a list of integers and a threshold value. Use a **lambda* function inside filter() to return a list of numbers greater than the threshold.
#
#
#   # Test the function with a list [1, 5, 10, 3, 8] and threshold 5

# %%
def myFunction(threshold, nums):
    return [x for x in nums if x > threshold]

numbers = [1, 5, 10, 3, 8]
t = 5
result = myFunction(t, numbers)
print(result)
# Out:
# [10, 8]

# %% [markdown]
# ### 3. Object-Oriented Programming (OOP)
#
# *Task*:
#
# * Implement a BankAccount class with methods for depositing, withdrawing, transferring, and checking balance.
# * Implement *Polymorphism* by overriding the __str__ method to provide a custom string representation of the account.
#
#
# # Example
# account_a = BankAccount("A123", "Alice", 1000)
#
# account_b = BankAccount("B456", "Bob", 500)
#
# account_a.deposit(200)
#
# account_a.transfer(300, account_b)

# %%
class BankAccount:
  def __init__(self,accNumber,Name,balance):
    self.accNumber=accNumber
    self.Name=Name
    self.balance=balance

  def deposit(self,amt):
    self.balance+=amt

  def withdraw(self,amt):
    if(self.balance>=amt):
      self.balance-=amt
    else:
      print("insufficient balance")

  def transfer(self,amt,acc):
    if(self.balance>=amt):
      self.balance-=amt
      acc.balance+=amt
    else:
      print("insufficient balance")

  def checkBalance(self):
    print("the balance of {} is {}".format(self.name,self.balance))

  def __str__(self):
    return "account number:{} name:{} balance:{}".format(self.accNumber,self.Name,self.balance)

acc1= BankAccount("A123","rhishit",10000)
acc2= BankAccount("B123","alice",50000)
acc1.deposit(2000)
acc2.withdraw(3000)
acc2.transfer(5000,acc1)
print(acc1)
print(acc2)
# Out:
# account number:A123 name:rhishit balance:17000
# account number:B123 name:alice balance:42000

# %% [markdown]
# ### 4. Exception Handling
#
# *Task*:
#
# * Write a divide_numbers(a, b) function with exception handling:
#
#   * Handle division by zero and invalid input (non-numeric values).
#
#
# # Test the function
# print(divide_numbers(10, 2))   # Valid input
#
# print(divide_numbers(10, 0))   # Division by zero
#
# print(divide_numbers("ten", 2))  # Invalid input

# %%
def divide_numbers(a, b):
    try:
        result = a / b
        return result
    except ZeroDivisionError:
        return "Error: Cannot divide by zero."
    except TypeError:
        return "Error: Both inputs must be numbers."

print(divide_numbers(10, 2))
print(divide_numbers(10, 0))
print(divide_numbers("ten", 2))
# Out:
# 5.0
# Error: Cannot divide by zero.
# Error: Both inputs must be numbers.

# %% [markdown]
# *Example Expected Output*:
#
#
# 5.0
#
# Cannot divide by zero
#
# Invalid input, please enter numbers

# %% [markdown]
# ### 5. Python Modules & File Handling
#
# *Task*:
#
# * Write a Python program to:
#
#   * Create a text file "students.txt" with student names and marks.
#   * Read the file and print names of students with marks above 80.

# %%
with open("students.txt", "w") as file:
    file.write("Alice 85\n")
    file.write("Bob 78\n")
    file.write("Charlie 92\n")
    file.write("David 67\n")
    file.write("Emma 88\n")

print("File 'students.txt' created successfully.")

print("\nStudents with marks above 80:")

with open("students.txt", "r") as file:
    for line in file:
        name, marks = line.strip().split()
        marks = int(marks)
        if marks > 80:
            print(name)
# Out:
# File 'students.txt' created successfully.
#
# Students with marks above 80:
# Alice
# Charlie
# Emma

# %% [markdown]
# *Expected Output*:
#
#
# Alice
#
# Bob
#
# David

# %% [markdown]
# ### 6. Regular Expressions
#
# *Task*:
#
# * Write a Python function extract_phone_numbers(text) that extracts all phone numbers from a given text. The phone numbers should be in the format (xxx) xxx-xxxx.
#
#
# sample_text = (
#     "For any support regarding our Bangalore office, call us at +91-9876543210 between 9 AM to 6 PM. "
#     "If you are located in Mumbai, you can also reach our helpdesk at 9123456789 for urgent assistance. "
#     "Additionally, our Delhi branch can be contacted at +91-9988776655 during weekdays."
# )
#
#
#
#
# *Expected Output*:
#
#
# ['+91-9876543210', '+91-9988776655']

# %%
def extract_phone_numbers(text):
    words = text.split()
    numbers = []

    for word in words:
        if word.startswith("+91-") and len(word) == 14:
            if word[4:].isdigit():
                numbers.append(word)
    return numbers


sample_text = (
    "For any support regarding our Bangalore office, call us at +91-9876543210 between 9 AM to 6 PM. "
    "If you are located in Mumbai, you can also reach our helpdesk at 9123456789 for urgent assistance. "
    "Additionally, our Delhi branch can be contacted at +91-9988776655 during weekdays."
)

print(extract_phone_numbers(sample_text))
# Out:
# ['+91-9876543210', '+91-9988776655']

# %% [markdown]
# *Expected Output*:
#
#
# ['+91-9876543210', '+91-9988776655']
